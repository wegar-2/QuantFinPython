# %% [markdown]
# ## Estimation of parameters of Geometric Brownian Motion

# %% [markdown]
# The script below uses data available at Stooq to find parameters for the GBM process that can be used to model the evolution of asstets prices
# NOTE: obviously it does not mean that the asset priced actually follow the GBM, because they do not -
# cf. below

# %%
# imports
import pandas as pd
import get_data_from_stooq
import numpy as np
import scipy.stats as spst
import math
import matplotlib.pyplot as plt
# %matplotlib notebook
import statsmodels.api

# %%
# prepare list of ticker symbols to analyze
list_of_tickers = ["tpe", "kgh", "peo", "lwb", "pkn", "lts", "opl"]

# %%
# get data from stooq
ts_start_date = "2011-01-01"
ts_end_date = "2016-12-31"
data_df = get_data_from_stooq.get_daily_data_from_stooq_for_tickers(list_of_tickers,
                                                                   ts_start_date,
                                                                   ts_end_date)
# Out:
# Ticker symbol in this iteration:  tpe
# Validation of start_date format result: positive...
# Validation of end_date format result: positive...
# Getting data from URL:  https://stooq.com/q/d/l/?s=tpe&d1=20110101&d2=20161231&i=d
# Ticker symbol in this iteration:  kgh
# Validation of start_date format result: positive...
# Validation of end_date format result: positive...
# Getting data from URL:  https://stooq.com/q/d/l/?s=kgh&d1=20110101&d2=20161231&i=d
# Ticker symbol in this iteration:  peo
# Validation of start_date format result: positive...
# Validation of end_date format result: positive...
# Getting data from URL:  https://stooq.com/q/d/l/?s=peo&d1=20110101&d2=20161231&i=d
# Ticker symbol in this iteration:  lwb
# Validation of start_date format result: positive...
# Validation of end_date format result: positive...
# Getting data from URL:  https://stooq.com/q/d/l/?s=lwb&d1=20110101&d2=20161231&i=d
# Ticker symbol in this iteration:  pkn
# ...

# %%
# printing a comparative plot of relative price changes
data_df_normd = data_df/data_df.iloc[0,:]
print("Head of normed data: ")
print(data_df_normd.head(3))
print("Tail of normed data: ")
print(data_df_normd.tail(3))
data_df_normd.plot()
plt.grid(True)
plt.title("Comparison of standardized performance over the analyzed period")
plt.xlabel("Time")
plt.ylabel("Standardized value/cumulative return")
# Out:
# Head of normed data:
#                  tpe       kgh       peo       lwb       pkn       lts  \
# Date
# 2011-01-03  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2011-01-04  1.006009  1.005853  1.003258  1.027021  0.968699  0.994920
# 2011-01-05  0.987983  0.979420  0.975861  1.035076  0.955582  0.975886
#
#                  opl
# Date
# 2011-01-03  1.000000
# 2011-01-04  0.917229
# 2011-01-05  0.931148
# Tail of normed data:
#                  tpe       kgh       peo       lwb       pkn       lts  \
# Date
# 2016-12-28  0.530173  0.868498  0.920770  0.791271  2.035745  1.148927
# 2016-12-29  0.532034  0.865666  0.938912  0.773760  2.026188  1.153111
# 2016-12-30  0.530173  0.873029  0.931507  0.760627  2.038134  1.142951
#
#                  opl
# Date
# 2016-12-28  0.438972
# 2016-12-29  0.443914
# 2016-12-30  0.453797
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %%
# calculating logarithmic returns for the data
data_df_logrr = pd.DataFrame(index=data_df.index)



# data_dict_in = {}

# for colname in data_df_logrr.columns.values:
    
print(data_df_logrr.head(3))
# Out:
# Empty DataFrame
# Columns: []
# Index: [2011-01-03 00:00:00, 2011-01-04 00:00:00, 2011-01-05 00:00:00]

# %%
# histograms for individual stocks

# %%
# descriptive statistics for individual stocks

# %%
# scatter plots matrix

# %%
# estimation of vector of average log RoRs

# %%
# estimation of the correlation matrix for log RoRs

# %%
# calculation of a value trajectory for a fictional portfolio and some basic analysis

# %%
# calculation of historical 1% VaR for the portfolio

# %%
# calculation of analytical 1% VaR for the porfolio

# %%
# calculation of simulational 1% VaR for the portfolio

# %%
# Fitting ARIMA models for the analysed stocks
